# %%
import torch
print("✅ CUDA available:", torch.cuda.is_available())
print("🖥️ Device:", torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Mount Drive (if not done yet)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ✅ CUDA available: True
# 🖥️ Device: cuda
# Mounted at /content/drive

# %% [markdown]
# **Regression**

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP1

# 平均Pearson Correlation: 0.47
# 平均Spearman Correlation: 0.39
# 平均R^2 Score: 0.17
# 平均RMSE: 0.88

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP1/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./"
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  45
# 	Batch size:             134
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          30
# 	Epochs:                 200
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 1 训练数据量: 2
# 1 验证数据量: 1
# ———————————————— 0.7410504817962646
# ————————
# ...

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2

# 平均Pearson Correlation: 0.33
# 平均Spearman Correlation: 0.28
# 平均R^2 Score: 0.05
# 平均RMSE: 0.94

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP2/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             30
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          30
# 	Epochs:                 200
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 1 训练数据量: 27
# 1 验证数据量: 1
# ———————————————— 0.7385071516036987
# ...

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_and_SP1

# 平均Pearson Correlation: 0.23
# 平均Spearman Correlation: 0.14
# 平均R^2 Score: 0.04
# 平均RMSE: 0.95

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/SP2_and_SP1/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1_and_SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_and_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             49
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          30
# 	Epochs:                 200
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1_and_SP2.xlsx
# 1 训练数据量: 20
# 1 验证数据量: 1
# ...

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1

# 平均Pearson Correlation: 0.49
# 平均Spearman Correlation: 0.39
# 平均R^2 Score: 0.17
# 平均RMSE: 0.87

# 🔁 Pretrain and Finetune CNN in one go
# !python3 pretrain_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--save_folder "./"

# !python3 finetune_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--pre_model_path "./CharCNN_best.pth.tar" \
--fine_model_path "./fine_CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx"
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             70
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          30
# 	Epochs:                 200
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              SGD
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 1 训练数据量: 11
# 1 验证数据量: 2
# ———————————————— 0.6043280512094498
# ————————
# ...

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP1

# 平均Pearson Correlation: 0.46
# 平均Spearman Correlation: 0.39
# 平均R^2 Score: 0.12
# 平均RMSE: 0.90

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP1/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--epochs 500 \
--batch_size 16 \
--embedding_dim 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 45
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  45
# 	Batch size:             16
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          32
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 1 训练数据量: 9
# 1 验证数据量: 1
# ———————————————— 0.8573096394538879
# ————————
# ...

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2

# 平均Pearson Correlation: 0.42
# 平均Spearman Correlation: 0.36
# 平均R^2 Score: 0.04
# 平均RMSE: 0.92

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP2/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./"
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             30
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          30
# 	Epochs:                 200
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 1 训练数据量: 27
# 1 验证数据量: 1
# ———————————————— 0.8194753527641296
# ...

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1

# 平均Pearson Correlation: 0.32
# 平均Spearman Correlation: 0.25
# 平均R^2 Score: -0.02
# 平均RMSE: 0.93

# 🔁 Pretrain and Finetune CNN in one go
# !python3 pretrain_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16

# !python3 finetune_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharCNN_best.pth.tar" \
--fine_model_path "./fine_CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 1 训练数据量: 22
# 1 验证数据量: 3
# ———————————————— 0.6511719822883606
# ————————
# ...

# %% [markdown]
# # BSP2 Dataset

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2

# 平均Pearson Correlation: 0.18
# 平均Spearman Correlation: 0.14
# 平均R^2 Score: -1.03
# 平均RMSE: 1.29

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP2/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 1 训练数据量: 8
# 1 验证数据量: 1
# ———————————————— 0.7163856625556946
# ...

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1

# 平均Pearson Correlation: 0.23
# 平均Spearman Correlation: 0.17
# 平均R^2 Score: -0.05
# 平均RMSE: 0.94

# !python3 pretrain_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16

# !python3 finetune_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharCNN_best.pth.tar" \
--fine_model_path "./fine_CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 1 训练数据量: 7
# 1 验证数据量: 1
# ———————————————— 1.0378093719482422
# ————————
# ...

# %% [markdown]
# # BSP3 Dataset

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2

# 平均Pearson Correlation: 0.29
# 平均Spearman Correlation: 0.29
# 平均R^2 Score: -0.10
# 平均RMSE: 1.01

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/only_SP2/train_CNN.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.03
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 1 训练数据量: 20
# 1 验证数据量: 1
# ———————————————— 0.7798295617103577
# ...

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1

# 平均Pearson Correlation: 0.22
# 平均Spearman Correlation: 0.19
# 平均R^2 Score: -0.06
# 平均RMSE: 0.96

# 🔁 BSP3 trans BSP1 - Pretrain and Finetune CNN in one go
# !python3 pretrain_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharCNN_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16

# !python3 finetune_CNN.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharCNN_best.pth.tar" \
--fine_model_path "./fine_CharCNN_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/regression/CNN/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharCNN_best.pth.tar
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 1 训练数据量: 18
# 1 验证数据量: 2
# ———————————————— 0.9752048254013062
# ————————
# ...
