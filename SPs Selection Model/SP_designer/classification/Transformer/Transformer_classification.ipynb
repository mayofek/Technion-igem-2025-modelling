# %%
import torch
print("✅ CUDA available:", torch.cuda.is_available())
print("🖥️ Device:", torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Mount Drive (if not done yet)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ✅ CUDA available: True
# 🖥️ Device: cuda
# Mounted at /content/drive

# %% [markdown]
# # Repeat Article Results

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP1

# [[92 10]
#  [19 30]]
# 平均准确率: 0.81
# 平均精确率: 0.81
# 平均召回率: 0.81
# 平均F1: 0.80

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 3 \
--hidden_dim 32 \
--num_heads 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP1
# 🔹 Running in Google Colab
# in collab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             32
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     3
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 训练集类别分布: {np.int64(0): 88, np.int64(1): 47}
# 1 训练数据量: 5
# 1 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 1: Done
# 1 准确率: 0.88
# 1 精确率: 0.77
# 1 召回率: 0.88
# 1 F1: 0.82
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 2 训练数据量: 5
# 2 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.69
# 2 召回率: 0.67
# 2 F1: 0.65
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 3 训练数据量: 5
# 3 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.73
# 3 召回率: 0.73
# 3 F1: 0.73
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 4 训练数据量: 5
# 4 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.80
# 4 精确率: 0.80
# 4 召回率: 0.80
# 4 F1: 0.80
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 5 训练数据量: 5
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.80
# 5 精确率: 0.85
# 5 召回率: 0.80
# 5 F1: 0.77
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 6 训练数据量: 5
# 6 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.87
# 6 精确率: 0.87
# 6 召回率: 0.87
# 6 F1: 0.87
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 7 训练数据量: 5
# 7 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.93
# 7 精确率: 0.94
# 7 召回率: 0.93
# 7 F1: 0.93
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 8 训练数据量: 5
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.73
# 8 精确率: 0.73
# 8 召回率: 0.73
# 8 F1: 0.73
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 9 训练数据量: 5
# 9 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.80
# 9 精确率: 0.83
# 9 召回率: 0.80
# 9 F1: 0.81
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 10 训练数据量: 5
# 10 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.87
# 10 精确率: 0.87
# 10 召回率: 0.87
# 10 F1: 0.87
#
# [[92 10]
#  [19 30]]
# 平均准确率: 0.81
# 平均精确率: 0.81
# 平均召回率: 0.81
# 平均F1: 0.80

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP2

# [[80 22]
#  [26 23]]
# 平均准确率: 0.68
# 平均精确率: 0.69
# 平均召回率: 0.68
# 平均F1: 0.66

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./"
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP2
# 🔹 Running in Google Colab
# in collab
# Directory already exists.
#
# Configuration:
# 	T max:                  100
# 	Batch size:             72
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.1
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 训练集类别分布: {np.int64(1): 291, np.int64(0): 492}
# 1 训练数据量: 11
# 1 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 1: Done
# 1 准确率: 0.88
# 1 精确率: 0.77
# 1 召回率: 0.88
# 1 F1: 0.82
#
# 2 训练数据量: 11
# 2 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.69
# 2 召回率: 0.67
# 2 F1: 0.65
#
# 3 训练数据量: 11
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.81
# 3 召回率: 0.73
# 3 F1: 0.67
#
# 4 训练数据量: 11
# 4 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.73
# 4 精确率: 0.76
# 4 召回率: 0.73
# 4 F1: 0.74
#
# 5 训练数据量: 11
# 5 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.60
# 5 精确率: 0.70
# 5 召回率: 0.60
# 5 F1: 0.61
#
# 6 训练数据量: 11
# 6 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.78
# 6 召回率: 0.80
# 6 F1: 0.78
#
# 7 训练数据量: 11
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.60
# 7 精确率: 0.43
# 7 召回率: 0.60
# 7 F1: 0.50
#
# 8 训练数据量: 11
# 8 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.53
# 8 精确率: 0.48
# 8 召回率: 0.53
# 8 F1: 0.49
#
# 9 训练数据量: 11
# 9 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.53
# 9 精确率: 0.74
# 9 召回率: 0.53
# 9 F1: 0.58
#
# 10 训练数据量: 11
# 10 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.73
# 10 精确率: 0.76
# 10 召回率: 0.73
# 10 F1: 0.73
#
# [[80 22]
#  [26 23]]
# 平均准确率: 0.68
# 平均精确率: 0.69
# 平均召回率: 0.68
# 平均F1: 0.66
# Copied file to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_16-34-57_saved_values.xlsx
# Log added successfully: ../../saved_values.xlsx at 2025-07-13 16:34:57
# File copied to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_16-34-57_saved_values.xlsx
# Log with parameters added successfully for classification_transformer
#
# ✅ Classification training results logged successfully!

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/SP2_and_SP1

# [[90 12]
#  [33 16]]
# 平均准确率: 0.70
# 平均精确率: 0.70
# 平均召回率: 0.70
# 平均F1: 0.67

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1_and_SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./"
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/SP2_and_SP1
# 🔹 Running in Google Colab
# in collab
# Directory already exists.
#
# Configuration:
# 	T max:                  50
# 	Batch size:             60
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.1
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1_and_SP2.xlsx
# 训练集类别分布: {np.int64(0): 594, np.int64(1): 340}
# 1 训练数据量: 16
# 1 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.88
# 1 精确率: 0.88
# 1 召回率: 0.88
# 1 F1: 0.88
#
# 2 训练数据量: 16
# 2 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.73
# 2 精确率: 0.75
# 2 召回率: 0.73
# 2 F1: 0.73
#
# 3 训练数据量: 16
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.81
# 3 召回率: 0.73
# 3 F1: 0.67
#
# 4 训练数据量: 16
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.67
# 4 精确率: 0.68
# 4 召回率: 0.67
# 4 F1: 0.67
#
# 5 训练数据量: 16
# 5 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.67
# 5 精确率: 0.65
# 5 召回率: 0.67
# 5 F1: 0.66
#
# 6 训练数据量: 16
# 6 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.78
# 6 召回率: 0.80
# 6 F1: 0.78
#
# 7 训练数据量: 16
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.44
# 7 召回率: 0.67
# 7 F1: 0.53
#
# 8 训练数据量: 16
# 8 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.67
# 8 精确率: 0.79
# 8 召回率: 0.67
# 8 F1: 0.58
#
# 9 训练数据量: 16
# 9 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.60
# 9 精确率: 0.60
# 9 召回率: 0.60
# 9 F1: 0.60
#
# 10 训练数据量: 16
# 10 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.60
# 10 精确率: 0.62
# 10 召回率: 0.60
# 10 F1: 0.56
#
# [[90 12]
#  [33 16]]
# 平均准确率: 0.70
# 平均精确率: 0.70
# 平均召回率: 0.70
# 平均F1: 0.67
# Copied file to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_16-47-13_saved_values.xlsx
# Log added successfully: ../../saved_values.xlsx at 2025-07-13 16:47:13
# File copied to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_16-47-13_saved_values.xlsx
# Log with parameters added successfully for classification_transformer
#
# ✅ Classification training results logged successfully!

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1

# [[96  6]
#  [37 12]]
# 平均准确率: 0.71
# 平均精确率: 0.74
# 平均召回率: 0.71
# 平均F1: 0.66

# 🔁 Pretrain and Finetune Transformer in one go
# !python3 pretrain_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16 \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4

# !python3 finetune_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--fine_model_path "./fine_CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--embedding_dim 16 \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  57
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 439}
# 1 训练数据量: 22
# 1 验证数据量: 3
# ———————————————— tensor(75.9494, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.76
# 1 精确率: 0.75
# 1 召回率: 0.76
# 1 F1: 0.74
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 442}
# 2 训练数据量: 22
# 2 验证数据量: 3
# ———————————————— tensor(84.8101, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.81
# 2 精确率: 0.82
# 2 召回率: 0.81
# 2 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 263, np.int64(0): 441}
# 3 训练数据量: 22
# 3 验证数据量: 3
# ———————————————— tensor(82.2785, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.78
# 3 精确率: 0.79
# 3 召回率: 0.78
# 3 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 267, np.int64(0): 438}
# 4 训练数据量: 23
# 4 验证数据量: 3
# ———————————————— tensor(87.1795, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.85
# 4 精确率: 0.85
# 4 召回率: 0.85
# 4 F1: 0.84
#
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 440}
# 5 训练数据量: 23
# 5 验证数据量: 3
# ———————————————— tensor(88.4615, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.85
# 5 精确率: 0.84
# 5 召回率: 0.85
# 5 F1: 0.84
#
# 训练集类别分布: {np.int64(1): 253, np.int64(0): 452}
# 6 训练数据量: 23
# 6 验证数据量: 3
# ———————————————— tensor(76.9231, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.75
# 6 召回率: 0.73
# 6 F1: 0.72
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 7 训练数据量: 23
# 7 验证数据量: 3
# ———————————————— tensor(79.4872, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.74
# 7 精确率: 0.77
# 7 召回率: 0.74
# 7 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 8 训练数据量: 23
# 8 验证数据量: 3
# ———————————————— tensor(84.6154, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.82
# 8 精确率: 0.84
# 8 召回率: 0.82
# 8 F1: 0.81
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 443}
# 9 训练数据量: 23
# 9 验证数据量: 3
# ———————————————— tensor(87.1795, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.79
# 9 精确率: 0.80
# 9 召回率: 0.79
# 9 F1: 0.79
#
# 训练集类别分布: {np.int64(1): 268, np.int64(0): 437}
# 10 训练数据量: 23
# 10 验证数据量: 3
# ———————————————— tensor(83.3333, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.81
# 10 精确率: 0.80
# 10 召回率: 0.81
# 10 F1: 0.80
#
# 平均准确率: 0.79
# 平均精确率: 0.80
# 平均召回率: 0.79
# 平均F1: 0.78
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(0): 88, np.int64(1): 47}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.75
# 1 精确率: 0.75
# 1 召回率: 0.75
# 1 F1: 0.75
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.80
# 2 精确率: 0.80
# 2 召回率: 0.80
# 2 F1: 0.80
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.81
# 3 召回率: 0.73
# 3 F1: 0.67
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.67
# 4 精确率: 0.79
# 4 召回率: 0.67
# 4 F1: 0.58
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.80
# 5 精确率: 0.85
# 5 召回率: 0.80
# 5 F1: 0.77
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.63
# 6 召回率: 0.73
# 6 F1: 0.68
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.63
# 7 召回率: 0.67
# 7 F1: 0.62
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.60
# 8 精确率: 0.57
# 8 召回率: 0.60
# 8 F1: 0.54
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.80
# 9 精确率: 0.84
# 9 召回率: 0.80
# 9 F1: 0.71
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.60
# 10 精确率: 0.77
# 10 召回率: 0.60
# 10 F1: 0.50
#
# [[96  6]
#  [37 12]]
# 平均准确率: 0.71
# 平均精确率: 0.74
# 平均召回率: 0.71
# 平均F1: 0.66

# %% [markdown]
# # Alexey Dataset ( BSP1 )

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP1

# [[102  11]
#  [ 12  23]]
# 平均准确率: 0.84
# 平均精确率: 0.85
# 平均召回率: 0.84
# 平均F1: 0.83

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 3 \
--hidden_dim 32 \
--num_heads 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP1
# 🔹 Running in Google Colab
# in collab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             32
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     3
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.80
# 1 精确率: 0.85
# 1 召回率: 0.80
# 1 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.87
# 2 精确率: 0.89
# 2 召回率: 0.87
# 2 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.87
# 3 精确率: 0.91
# 3 召回率: 0.87
# 3 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.80
# 4 精确率: 0.81
# 4 召回率: 0.80
# 4 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.93
# 5 召回率: 0.87
# 5 F1: 0.88
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.93
# 6 精确率: 0.95
# 6 召回率: 0.93
# 6 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.81
# 7 召回率: 0.80
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 8: Done
# 8 准确率: 0.93
# 8 精确率: 0.87
# 8 召回率: 0.93
# 8 F1: 0.90
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.71
# 9 精确率: 0.71
# 9 召回率: 0.71
# 9 F1: 0.71
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# ———————————————— tensor(92.8571, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 10: Done
# 10 准确率: 0.86
# 10 精确率: 0.73
# 10 召回率: 0.86
# 10 F1: 0.79
#
# [[102  11]
#  [ 12  23]]
# 平均准确率: 0.84
# 平均精确率: 0.85
# 平均召回率: 0.84
# 平均F1: 0.83
# Copied file to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_04-43-52_saved_values.xlsx
# Log added successfully: ../../saved_values.xlsx at 2025-07-13 04:43:52
# File copied to: /content/drive/MyDrive/Colab Notebooks/repo/utils/history_files/2025-07-13_04-43-52_saved_values.xlsx
# Log with parameters added successfully for classification_transformer
#
# ✅ Classification training results logged successfully!

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP2

# [[86 27]
#  [26  9]]
# 平均准确率: 0.64
# 平均精确率: 0.67
# 平均召回率: 0.64
# 平均F1: 0.64

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 400 \
--batch_size 32 \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  100
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 400
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 训练集类别分布: {np.int64(1): 291, np.int64(0): 492}
# 1 训练数据量: 25
# 1 验证数据量: 1
# ———————————————— tensor(53.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.47
# 1 精确率: 0.56
# 1 召回率: 0.47
# 1 F1: 0.48
#
# 2 训练数据量: 25
# 2 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.53
# 2 精确率: 0.51
# 2 召回率: 0.53
# 2 F1: 0.52
#
# 3 训练数据量: 25
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.67
# 3 精确率: 0.52
# 3 召回率: 0.67
# 3 F1: 0.59
#
# 4 训练数据量: 25
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.67
# 4 精确率: 0.63
# 4 召回率: 0.67
# 4 F1: 0.62
#
# 5 训练数据量: 25
# 5 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.67
# 5 精确率: 0.72
# 5 召回率: 0.67
# 5 F1: 0.69
#
# 6 训练数据量: 25
# 6 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.73
# 6 召回率: 0.73
# 6 F1: 0.73
#
# 7 训练数据量: 25
# 7 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.85
# 7 召回率: 0.80
# 7 F1: 0.77
#
# 8 训练数据量: 25
# 8 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.53
# 8 精确率: 0.83
# 8 召回率: 0.53
# 8 F1: 0.65
#
# 9 训练数据量: 25
# 9 验证数据量: 1
# ———————————————— tensor(78.5714, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.64
# 9 精确率: 0.59
# 9 召回率: 0.64
# 9 F1: 0.61
#
# 10 训练数据量: 25
# 10 验证数据量: 1
# ———————————————— tensor(78.5714, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.71
# 10 精确率: 0.81
# 10 召回率: 0.71
# 10 F1: 0.75
#
# [[86 27]
#  [26  9]]
# 平均准确率: 0.64
# 平均精确率: 0.67
# 平均召回率: 0.64
# 平均F1: 0.64

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1

# [[98 15]
#  [22 13]]
# 平均准确率: 0.75
# 平均精确率: 0.77
# 平均召回率: 0.75
# 平均F1: 0.71

# !python3 pretrain_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4

# !python3 finetune_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--fine_model_path "./fine_CharTransformer_best_SP2TOBSP1.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  57
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 439}
# 1 训练数据量: 22
# 1 验证数据量: 3
# ———————————————— tensor(78.4810, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.73
# 1 精确率: 0.73
# 1 召回率: 0.73
# 1 F1: 0.70
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 442}
# 2 训练数据量: 22
# 2 验证数据量: 3
# ———————————————— tensor(81.0127, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.76
# 2 精确率: 0.76
# 2 召回率: 0.76
# 2 F1: 0.74
#
# 训练集类别分布: {np.int64(1): 263, np.int64(0): 441}
# 3 训练数据量: 22
# 3 验证数据量: 3
# ———————————————— tensor(77.2152, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.71
# 3 精确率: 0.71
# 3 召回率: 0.71
# 3 F1: 0.67
#
# 训练集类别分布: {np.int64(1): 267, np.int64(0): 438}
# 4 训练数据量: 23
# 4 验证数据量: 3
# ———————————————— tensor(76.9231, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.74
# 4 精确率: 0.75
# 4 召回率: 0.74
# 4 F1: 0.70
#
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 440}
# 5 训练数据量: 23
# 5 验证数据量: 3
# ———————————————— tensor(83.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.81
# 5 精确率: 0.80
# 5 召回率: 0.81
# 5 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 253, np.int64(0): 452}
# 6 训练数据量: 23
# 6 验证数据量: 3
# ———————————————— tensor(74.3590, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.65
# 6 精确率: 0.71
# 6 召回率: 0.65
# 6 F1: 0.62
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 7 训练数据量: 23
# 7 验证数据量: 3
# ———————————————— tensor(70.5128, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.75
# 7 召回率: 0.67
# 7 F1: 0.61
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 8 训练数据量: 23
# 8 验证数据量: 3
# ———————————————— tensor(74.3590, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.67
# 8 精确率: 0.70
# 8 召回率: 0.67
# 8 F1: 0.63
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 443}
# 9 训练数据量: 23
# 9 验证数据量: 3
# ———————————————— tensor(78.2051, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.73
# 9 精确率: 0.74
# 9 召回率: 0.73
# 9 F1: 0.70
#
# 训练集类别分布: {np.int64(1): 268, np.int64(0): 437}
# 10 训练数据量: 23
# 10 验证数据量: 3
# ———————————————— tensor(82.0513, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.77
# 10 精确率: 0.76
# 10 召回率: 0.77
# 10 F1: 0.75
#
# 平均准确率: 0.72
# 平均精确率: 0.74
# 平均召回率: 0.72
# 平均F1: 0.69
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.67
# 1 精确率: 0.65
# 1 召回率: 0.67
# 1 F1: 0.66
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.69
# 2 召回率: 0.67
# 2 F1: 0.67
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.80
# 3 召回率: 0.73
# 3 F1: 0.62
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.60
# 4 精确率: 0.70
# 4 召回率: 0.60
# 4 F1: 0.61
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.88
# 5 召回率: 0.87
# 5 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.84
# 6 召回率: 0.80
# 6 F1: 0.71
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.73
# 7 精确率: 0.77
# 7 召回率: 0.73
# 7 F1: 0.74
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.87
# 8 精确率: 0.87
# 8 召回率: 0.87
# 8 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(78.5714, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.71
# 9 精确率: 0.60
# 9 召回率: 0.71
# 9 F1: 0.65
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.86
# 10 精确率: 0.88
# 10 召回率: 0.86
# 10 F1: 0.79
#
# [[98 15]
#  [22 13]]
# 平均准确率: 0.75
# 平均精确率: 0.77
# 平均召回率: 0.75
# 平均F1: 0.71

# %% [markdown]
# # BSP2 Dataset

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP2

# [[94 19]
#  [25 10]]
# 平均准确率: 0.70
# 平均精确率: 0.68
# 平均召回率: 0.70
# 平均F1: 0.69

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 3 \
--hidden_dim 32 \
--num_heads 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  100
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             32
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     3
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 训练集类别分布: {np.int64(1): 54, np.int64(0): 183}
# 1 训练数据量: 8
# 1 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.60
# 1 精确率: 0.56
# 1 召回率: 0.60
# 1 F1: 0.57
#
# 2 训练数据量: 8
# 2 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.73
# 2 精确率: 0.73
# 2 召回率: 0.73
# 2 F1: 0.73
#
# 3 训练数据量: 8
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.54
# 3 召回率: 0.73
# 3 F1: 0.62
#
# 4 训练数据量: 8
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.53
# 4 精确率: 0.56
# 4 召回率: 0.53
# 4 F1: 0.54
#
# 5 训练数据量: 8
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.75
# 5 召回率: 0.87
# 5 F1: 0.80
#
# 6 训练数据量: 8
# 6 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.80
# 6 召回率: 0.73
# 6 F1: 0.75
#
# 7 训练数据量: 8
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.60
# 7 精确率: 0.56
# 7 召回率: 0.60
# 7 F1: 0.57
#
# 8 训练数据量: 8
# 8 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.73
# 8 精确率: 0.86
# 8 召回率: 0.73
# 8 F1: 0.79
#
# 9 训练数据量: 8
# 9 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.79
# 9 精确率: 0.76
# 9 召回率: 0.79
# 9 F1: 0.77
#
# 10 训练数据量: 8
# 10 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.71
# 10 精确率: 0.71
# 10 召回率: 0.71
# 10 F1: 0.71
#
# [[94 19]
#  [25 10]]
# 平均准确率: 0.70
# 平均精确率: 0.68
# 平均召回率: 0.70
# 平均F1: 0.69

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1

# [[84 29]
#  [13 22]]
# 平均准确率: 0.71
# 平均精确率: 0.77
# 平均召回率: 0.71
# 平均F1: 0.72

# !python3 pretrain_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4

# !python3 finetune_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--fine_model_path "./fine_CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  57
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 1 训练数据量: 7
# 1 验证数据量: 1
# ———————————————— tensor(83.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.75
# 1 精确率: 0.88
# 1 召回率: 0.75
# 1 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 2 训练数据量: 7
# 2 验证数据量: 1
# ———————————————— tensor(79.1667, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.79
# 2 精确率: 0.89
# 2 召回率: 0.79
# 2 F1: 0.81
#
# 训练集类别分布: {np.int64(1): 53, np.int64(0): 160}
# 3 训练数据量: 7
# 3 验证数据量: 1
# ———————————————— tensor(75., device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.67
# 3 精确率: 0.96
# 3 召回率: 0.67
# 3 F1: 0.76
#
# 训练集类别分布: {np.int64(1): 47, np.int64(0): 166}
# 4 训练数据量: 7
# 4 验证数据量: 1
# ———————————————— tensor(83.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.75
# 4 精确率: 0.75
# 4 召回率: 0.75
# 4 F1: 0.75
#
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 5 训练数据量: 7
# 5 验证数据量: 1
# ———————————————— tensor(75., device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.67
# 5 精确率: 0.74
# 5 召回率: 0.67
# 5 F1: 0.69
#
# 训练集类别分布: {np.int64(1): 47, np.int64(0): 166}
# 6 训练数据量: 7
# 6 验证数据量: 1
# ———————————————— tensor(91.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.79
# 6 精确率: 0.80
# 6 召回率: 0.79
# 6 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 46, np.int64(0): 167}
# 7 训练数据量: 7
# 7 验证数据量: 1
# ———————————————— tensor(70.8333, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.72
# 7 召回率: 0.67
# 7 F1: 0.68
#
# 训练集类别分布: {np.int64(1): 49, np.int64(0): 165}
# 8 训练数据量: 7
# 8 验证数据量: 1
# ———————————————— tensor(73.9130, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.70
# 8 精确率: 0.81
# 8 召回率: 0.70
# 8 F1: 0.72
#
# 训练集类别分布: {np.int64(1): 50, np.int64(0): 164}
# 9 训练数据量: 7
# 9 验证数据量: 1
# ———————————————— tensor(78.2609, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.65
# 9 精确率: 0.81
# 9 召回率: 0.65
# 9 F1: 0.69
#
# 训练集类别分布: {np.int64(1): 50, np.int64(0): 164}
# 10 训练数据量: 7
# 10 验证数据量: 1
# ———————————————— tensor(78.2609, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.61
# 10 精确率: 0.80
# 10 召回率: 0.61
# 10 F1: 0.66
#
# 平均准确率: 0.70
# 平均精确率: 0.82
# 平均召回率: 0.70
# 平均F1: 0.73
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.73
# 1 精确率: 0.73
# 1 召回率: 0.73
# 1 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.87
# 2 精确率: 0.90
# 2 召回率: 0.87
# 2 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.47
# 3 精确率: 0.59
# 3 召回率: 0.47
# 3 F1: 0.50
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.53
# 4 精确率: 0.67
# 4 召回率: 0.53
# 4 F1: 0.53
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.80
# 5 精确率: 0.74
# 5 召回率: 0.80
# 5 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.78
# 6 召回率: 0.80
# 6 F1: 0.78
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.81
# 7 召回率: 0.80
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.93
# 8 精确率: 0.94
# 8 召回率: 0.93
# 8 F1: 0.90
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(71.4286, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.64
# 9 精确率: 0.87
# 9 召回率: 0.64
# 9 F1: 0.67
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(78.5714, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.57
# 10 精确率: 0.69
# 10 召回率: 0.57
# 10 F1: 0.62
#
# [[84 29]
#  [13 22]]
# 平均准确率: 0.71
# 平均精确率: 0.77
# 平均召回率: 0.71
# 平均F1: 0.72

# %% [markdown]
# # BSP3 Dataset

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/only_SP2

# [[89 24]
#  [18 17]]
# 平均准确率: 0.72
# 平均精确率: 0.78
# 平均召回率: 0.72
# 平均F1: 0.72

# !python3 train_Transformer.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 3 \
--hidden_dim 32 \
--num_heads 4
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  100
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             32
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     3
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 训练集类别分布: {np.int64(1): 240, np.int64(0): 398}
# 1 训练数据量: 20
# 1 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.67
# 1 精确率: 0.63
# 1 召回率: 0.67
# 1 F1: 0.62
#
# 2 训练数据量: 20
# 2 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.80
# 2 精确率: 0.85
# 2 召回率: 0.80
# 2 F1: 0.77
#
# 3 训练数据量: 20
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.73
# 3 召回率: 0.73
# 3 F1: 0.73
#
# 4 训练数据量: 20
# 4 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.67
# 4 精确率: 0.65
# 4 召回率: 0.67
# 4 F1: 0.66
#
# 5 训练数据量: 20
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.75
# 5 召回率: 0.87
# 5 F1: 0.80
#
# 6 训练数据量: 20
# 6 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.60
# 6 精确率: 0.76
# 6 召回率: 0.60
# 6 F1: 0.64
#
# 7 训练数据量: 20
# 7 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.80
# 7 召回率: 0.80
# 7 F1: 0.79
#
# 8 训练数据量: 20
# 8 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.67
# 8 精确率: 0.94
# 8 召回率: 0.67
# 8 F1: 0.75
#
# 9 训练数据量: 20
# 9 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.71
# 9 精确率: 0.78
# 9 召回率: 0.71
# 9 F1: 0.74
#
# 10 训练数据量: 20
# 10 验证数据量: 1
# ———————————————— tensor(78.5714, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.64
# 10 精确率: 0.90
# 10 召回率: 0.64
# 10 F1: 0.70
#
# [[89 24]
#  [18 17]]
# 平均准确率: 0.72
# 平均精确率: 0.78
# 平均召回率: 0.72
# 平均F1: 0.72

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1

# [[86 27]
#  [ 5 30]]
# 平均准确率: 0.78
# 平均精确率: 0.85
# 平均召回率: 0.78
# 平均F1: 0.80

# !python3 pretrain_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4

# !python3 finetune_Transformer.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharTransformer_best.pth.tar" \
--fine_model_path "./fine_CharTransformer_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--num_encoder_layers 2 \
--hidden_dim 12 \
--num_heads 4 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/Transformer/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  57
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Hidden dim:             12
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharTransformer_best.pth.tar
# 	Num classes:            2
# 	Num encoder layers:     2
# 	Num heads:              4
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 213, np.int64(0): 361}
# 1 训练数据量: 18
# 1 验证数据量: 2
# ———————————————— tensor(79.6875, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.73
# 1 精确率: 0.73
# 1 召回率: 0.73
# 1 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 217, np.int64(0): 357}
# 2 训练数据量: 18
# 2 验证数据量: 2
# ———————————————— tensor(75., device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.68
# 2 召回率: 0.67
# 2 F1: 0.68
#
# 训练集类别分布: {np.int64(1): 211, np.int64(0): 363}
# 3 训练数据量: 18
# 3 验证数据量: 2
# ———————————————— tensor(84.3750, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.73
# 3 召回率: 0.73
# 3 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 219, np.int64(0): 355}
# 4 训练数据量: 18
# 4 验证数据量: 2
# ———————————————— tensor(84.3750, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.75
# 4 精确率: 0.74
# 4 召回率: 0.75
# 4 F1: 0.75
#
# 训练集类别分布: {np.int64(1): 213, np.int64(0): 361}
# 5 训练数据量: 18
# 5 验证数据量: 2
# ———————————————— tensor(76.5625, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.66
# 5 精确率: 0.68
# 5 召回率: 0.66
# 5 F1: 0.66
#
# 训练集类别分布: {np.int64(1): 216, np.int64(0): 358}
# 6 训练数据量: 18
# 6 验证数据量: 2
# ———————————————— tensor(84.3750, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.80
# 6 召回率: 0.80
# 6 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 221, np.int64(0): 353}
# 7 训练数据量: 18
# 7 验证数据量: 2
# ———————————————— tensor(81.2500, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.77
# 7 精确率: 0.75
# 7 召回率: 0.77
# 7 F1: 0.75
#
# 训练集类别分布: {np.int64(1): 214, np.int64(0): 360}
# 8 训练数据量: 18
# 8 验证数据量: 2
# ———————————————— tensor(82.8125, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.73
# 8 精确率: 0.73
# 8 召回率: 0.73
# 8 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 219, np.int64(0): 356}
# 9 训练数据量: 18
# 9 验证数据量: 2
# ———————————————— tensor(84.1270, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.83
# 9 精确率: 0.83
# 9 召回率: 0.83
# 9 F1: 0.83
#
# 训练集类别分布: {np.int64(1): 217, np.int64(0): 358}
# 10 训练数据量: 18
# 10 验证数据量: 2
# ———————————————— tensor(84.1270, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.76
# 10 精确率: 0.76
# 10 召回率: 0.76
# 10 F1: 0.76
#
# 平均准确率: 0.74
# 平均精确率: 0.74
# 平均召回率: 0.74
# 平均F1: 0.74
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.67
# 1 精确率: 0.69
# 1 召回率: 0.67
# 1 F1: 0.67
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.74
# 2 召回率: 0.67
# 2 F1: 0.68
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.60
# 3 精确率: 0.84
# 3 召回率: 0.60
# 3 F1: 0.61
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.87
# 4 精确率: 0.90
# 4 召回率: 0.87
# 4 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.73
# 5 精确率: 0.82
# 5 召回率: 0.73
# 5 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.87
# 6 精确率: 0.92
# 6 召回率: 0.87
# 6 F1: 0.88
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.81
# 7 召回率: 0.80
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.93
# 8 精确率: 0.97
# 8 召回率: 0.93
# 8 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(92.8571, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.86
# 9 精确率: 0.91
# 9 召回率: 0.86
# 9 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.86
# 10 精确率: 0.93
# 10 召回率: 0.86
# 10 F1: 0.87
#
# [[86 27]
#  [ 5 30]]
# 平均准确率: 0.78
# 平均精确率: 0.85
# 平均召回率: 0.78
# 平均F1: 0.80
