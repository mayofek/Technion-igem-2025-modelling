# %%
import torch
print("✅ CUDA available:", torch.cuda.is_available())
print("🖥️ Device:", torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Mount Drive (if not done yet)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ✅ CUDA available: True
# 🖥️ Device: cuda
# Mounted at /content/drive

# %% [markdown]
# # Repeat Article Results

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP1

# [[98  4]
#  [29 20]]
# 平均准确率: 0.78
# 平均精确率: 0.75
# 平均召回率: 0.78
# 平均F1: 0.74

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/only_SP1/train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--max_norm 400 \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.3 \
--embedding_dim 8 \
--max_length 50 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          8
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              Adam
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 训练集类别分布: {np.int64(0): 88, np.int64(1): 47}
# 1 训练数据量: 5
# 1 验证数据量: 1
# ———————————————— tensor(93.7500, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 1: Done
# 1 准确率: 0.88
# 1 精确率: 0.77
# 1 召回率: 0.88
# 1 F1: 0.82
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 2 训练数据量: 5
# 2 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.80
# 2 精确率: 0.80
# 2 召回率: 0.80
# 2 F1: 0.80
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 3 训练数据量: 5
# 3 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.80
# 3 精确率: 0.85
# 3 召回率: 0.80
# 3 F1: 0.77
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 4 训练数据量: 5
# 4 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.80
# 4 精确率: 0.80
# 4 召回率: 0.80
# 4 F1: 0.80
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 5 训练数据量: 5
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.89
# 5 召回率: 0.87
# 5 F1: 0.86
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 6 训练数据量: 5
# 6 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.87
# 6 精确率: 0.89
# 6 召回率: 0.87
# 6 F1: 0.84
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 7 训练数据量: 5
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.44
# 7 召回率: 0.67
# 7 F1: 0.53
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 8 训练数据量: 5
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.67
# 8 精确率: 0.66
# 8 召回率: 0.67
# 8 F1: 0.66
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 9 训练数据量: 5
# 9 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 9: Done
# 9 准确率: 0.80
# 9 精确率: 0.64
# 9 召回率: 0.80
# 9 F1: 0.71
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 10 训练数据量: 5
# 10 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.67
# 10 精确率: 0.79
# 10 召回率: 0.67
# 10 F1: 0.61
#
# [[98  4]
#  [29 20]]
# 平均准确率: 0.78
# 平均精确率: 0.75
# 平均召回率: 0.78
# 平均F1: 0.74

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2

# [[73 29]
#  [32 17]]
# 平均准确率: 0.60
# 平均精确率: 0.56
# 平均召回率: 0.60
# 平均F1: 0.56

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/only_SP2/train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--saved_values_path "./saved_values.xlsx" \
--epochs 500 \
--batch_size 64 \
--lr_min 0.0001 \
--embedding_dim 16
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             64
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          16
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.05
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 训练集类别分布: {np.int64(1): 291, np.int64(0): 492}
# 1 训练数据量: 13
# 1 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.69
# 1 精确率: 0.91
# 1 召回率: 0.69
# 1 F1: 0.74
#
# 2 训练数据量: 13
# 2 验证数据量: 1
# ———————————————— tensor(53.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.47
# 2 精确率: 0.47
# 2 召回率: 0.47
# 2 F1: 0.46
#
# 3 训练数据量: 13
# 3 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.53
# 3 精确率: 0.56
# 3 召回率: 0.53
# 3 F1: 0.54
#
# 4 训练数据量: 13
# 4 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 4: Done
# 4 准确率: 0.60
# 4 精确率: 0.36
# 4 召回率: 0.60
# 4 F1: 0.45
#
# 5 训练数据量: 13
# 5 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.60
# 5 精确率: 0.64
# 5 召回率: 0.60
# 5 F1: 0.61
#
# 6 训练数据量: 13
# 6 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.73
# 6 召回率: 0.73
# 6 F1: 0.73
#
# 7 训练数据量: 13
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.44
# 7 召回率: 0.67
# 7 F1: 0.53
#
# 8 训练数据量: 13
# 8 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.60
# 8 精确率: 0.57
# 8 召回率: 0.60
# 8 F1: 0.54
#
# 9 训练数据量: 13
# 9 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.73
# 9 精确率: 0.63
# 9 召回率: 0.73
# 9 F1: 0.68
#
# 10 训练数据量: 13
# 10 验证数据量: 1
# ———————————————— tensor(60.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.33
# 10 精确率: 0.30
# 10 召回率: 0.33
# 10 F1: 0.30
#
# [[73 29]
#  [32 17]]
# 平均准确率: 0.60
# 平均精确率: 0.56
# 平均召回率: 0.60
# 平均F1: 0.56

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1

# [[94  8]
#  [23 26]]
# 平均准确率: 0.79
# 平均精确率: 0.81
# 平均召回率: 0.79
# 平均F1: 0.78

# !python3 pretrain_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2

# !python3 finetune_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx" \
--pre_model_path "./CharMLP_best.pth.tar" \
--fine_model_path "./fine_CharMLP_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP1.xlsx
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 439}
# 1 训练数据量: 22
# 1 验证数据量: 3
# ———————————————— tensor(96.2025, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.92
# 1 精确率: 0.92
# 1 召回率: 0.92
# 1 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 442}
# 2 训练数据量: 22
# 2 验证数据量: 3
# ———————————————— tensor(93.6709, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.92
# 2 精确率: 0.92
# 2 召回率: 0.92
# 2 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 263, np.int64(0): 441}
# 3 训练数据量: 22
# 3 验证数据量: 3
# ———————————————— tensor(94.9367, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.92
# 3 精确率: 0.92
# 3 召回率: 0.92
# 3 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 267, np.int64(0): 438}
# 4 训练数据量: 23
# 4 验证数据量: 3
# ———————————————— tensor(93.5897, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.91
# 4 精确率: 0.91
# 4 召回率: 0.91
# 4 F1: 0.91
#
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 440}
# 5 训练数据量: 23
# 5 验证数据量: 3
# ———————————————— tensor(97.4359, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.97
# 5 精确率: 0.98
# 5 召回率: 0.97
# 5 F1: 0.97
#
# 训练集类别分布: {np.int64(1): 253, np.int64(0): 452}
# 6 训练数据量: 23
# 6 验证数据量: 3
# ———————————————— tensor(87.1795, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.81
# 6 精确率: 0.86
# 6 召回率: 0.81
# 6 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 7 训练数据量: 23
# 7 验证数据量: 3
# ———————————————— tensor(82.0513, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.81
# 7 精确率: 0.84
# 7 召回率: 0.81
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 8 训练数据量: 23
# 8 验证数据量: 3
# ———————————————— tensor(94.8718, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.95
# 8 精确率: 0.95
# 8 召回率: 0.95
# 8 F1: 0.95
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 443}
# 9 训练数据量: 23
# 9 验证数据量: 3
# ———————————————— tensor(93.5897, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.92
# 9 精确率: 0.93
# 9 召回率: 0.92
# 9 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 268, np.int64(0): 437}
# 10 训练数据量: 23
# 10 验证数据量: 3
# ———————————————— tensor(96.1538, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.95
# 10 精确率: 0.95
# 10 召回率: 0.95
# 10 F1: 0.95
#
# 平均准确率: 0.91
# 平均精确率: 0.92
# 平均召回率: 0.91
# 平均F1: 0.91
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(0): 88, np.int64(1): 47}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.88
# 1 精确率: 0.89
# 1 召回率: 0.88
# 1 F1: 0.82
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.67
# 2 精确率: 0.79
# 2 召回率: 0.67
# 2 F1: 0.61
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.67
# 3 精确率: 0.63
# 3 召回率: 0.67
# 3 F1: 0.62
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.73
# 4 精确率: 0.73
# 4 召回率: 0.73
# 4 F1: 0.73
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.89
# 5 召回率: 0.87
# 5 F1: 0.86
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.73
# 6 精确率: 0.73
# 6 召回率: 0.73
# 6 F1: 0.73
#
# 训练集类别分布: {np.int64(0): 92, np.int64(1): 44}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.87
# 7 精确率: 0.90
# 7 召回率: 0.87
# 7 F1: 0.87
#
# 训练集类别分布: {np.int64(0): 93, np.int64(1): 43}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.73
# 8 精确率: 0.74
# 8 召回率: 0.73
# 8 F1: 0.72
#
# 训练集类别分布: {np.int64(0): 90, np.int64(1): 46}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.93
# 9 精确率: 0.94
# 9 召回率: 0.93
# 9 F1: 0.93
#
# 训练集类别分布: {np.int64(0): 94, np.int64(1): 42}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.87
# 10 精确率: 0.89
# 10 召回率: 0.87
# 10 F1: 0.86
#
# [[94  8]
#  [23 26]]
# 平均准确率: 0.79
# 平均精确率: 0.81
# 平均召回率: 0.79
# 平均F1: 0.78

# %% [markdown]
# # Alexey Dataset ( BSP1 )

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP1

# [[79 34]
#  [13 22]]
# 平均准确率: 0.68
# 平均精确率: 0.78
# 平均召回率: 0.68
# 平均F1: 0.70

# !python3 train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--saved_values_path "./saved_values.xlsx" \
--lr_min 0.0001 \
--epochs 500 \
--batch_size 32 \
--embedding_dim 32
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.3
# 	Embedding dim:          8
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.05
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.53
# 1 精确率: 0.56
# 1 召回率: 0.53
# 1 F1: 0.54
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.73
# 2 精确率: 0.77
# 2 召回率: 0.73
# 2 F1: 0.74
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.80
# 3 精确率: 0.89
# 3 召回率: 0.80
# 3 F1: 0.81
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.73
# 4 精确率: 0.73
# 4 召回率: 0.73
# 4 F1: 0.73
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.53
# 5 精确率: 0.69
# 5 召回率: 0.53
# 5 F1: 0.60
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.87
# 6 精确率: 0.87
# 6 召回率: 0.87
# 6 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.80
# 7 精确率: 0.81
# 7 召回率: 0.80
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.53
# 8 精确率: 0.94
# 8 召回率: 0.53
# 8 F1: 0.64
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.64
# 9 精确率: 0.59
# 9 召回率: 0.64
# 9 F1: 0.61
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.64
# 10 精确率: 0.90
# 10 召回率: 0.64
# 10 F1: 0.70
#
# [[79 34]
#  [13 22]]
# 平均准确率: 0.68
# 平均精确率: 0.78
# 平均召回率: 0.68
# 平均F1: 0.70

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2

# [[74 39]
#  [26  9]]
# 平均准确率: 0.56
# 平均精确率: 0.61
# 平均召回率: 0.56
# 平均F1: 0.56

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/only_SP2/train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 500 \
--batch_size 32 \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 训练集类别分布: {np.int64(1): 291, np.int64(0): 492}
# 1 训练数据量: 25
# 1 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.67
# 1 精确率: 0.74
# 1 召回率: 0.67
# 1 F1: 0.68
#
# 2 训练数据量: 25
# 2 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.33
# 2 精确率: 0.38
# 2 召回率: 0.33
# 2 F1: 0.35
#
# 3 训练数据量: 25
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.40
# 3 精确率: 0.55
# 3 召回率: 0.40
# 3 F1: 0.43
#
# 4 训练数据量: 25
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.60
# 4 精确率: 0.43
# 4 召回率: 0.60
# 4 F1: 0.50
#
# 5 训练数据量: 25
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.80
# 5 精确率: 0.84
# 5 召回率: 0.80
# 5 F1: 0.82
#
# 6 训练数据量: 25
# 6 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.53
# 6 精确率: 0.58
# 6 召回率: 0.53
# 6 F1: 0.56
#
# 7 训练数据量: 25
# 7 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 7: Done
# 7 准确率: 0.67
# 7 精确率: 0.44
# 7 召回率: 0.67
# 7 F1: 0.53
#
# 8 训练数据量: 25
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.67
# 8 精确率: 0.94
# 8 召回率: 0.67
# 8 F1: 0.75
#
# 9 训练数据量: 25
# 9 验证数据量: 1
# ———————————————— tensor(92.8571, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.36
# 9 精确率: 0.49
# 9 召回率: 0.36
# 9 F1: 0.41
#
# 10 训练数据量: 25
# 10 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.57
# 10 精确率: 0.69
# 10 召回率: 0.57
# 10 F1: 0.62
#
# [[74 39]
#  [26  9]]
# 平均准确率: 0.56
# 平均精确率: 0.61
# 平均召回率: 0.56
# 平均F1: 0.56

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1

# [[100  13]
#  [  5  30]]
# 平均准确率: 0.88
# 平均精确率: 0.90
# 平均召回率: 0.88
# 平均F1: 0.88

# 🔁 Pretrain and Finetune MLP in one go
# !python3 pretrain_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2

# !python3 finetune_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharMLP_best.pth.tar" \
--fine_model_path "./fine_CharMLP_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/SP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 439}
# 1 训练数据量: 22
# 1 验证数据量: 3
# ———————————————— tensor(96.2025, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.92
# 1 精确率: 0.92
# 1 召回率: 0.92
# 1 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 442}
# 2 训练数据量: 22
# 2 验证数据量: 3
# ———————————————— tensor(93.6709, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.92
# 2 精确率: 0.92
# 2 召回率: 0.92
# 2 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 263, np.int64(0): 441}
# 3 训练数据量: 22
# 3 验证数据量: 3
# ———————————————— tensor(94.9367, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.92
# 3 精确率: 0.92
# 3 召回率: 0.92
# 3 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 267, np.int64(0): 438}
# 4 训练数据量: 23
# 4 验证数据量: 3
# ———————————————— tensor(93.5897, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.91
# 4 精确率: 0.91
# 4 召回率: 0.91
# 4 F1: 0.91
#
# 训练集类别分布: {np.int64(1): 265, np.int64(0): 440}
# 5 训练数据量: 23
# 5 验证数据量: 3
# ———————————————— tensor(97.4359, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.97
# 5 精确率: 0.98
# 5 召回率: 0.97
# 5 F1: 0.97
#
# 训练集类别分布: {np.int64(1): 253, np.int64(0): 452}
# 6 训练数据量: 23
# 6 验证数据量: 3
# ———————————————— tensor(87.1795, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.81
# 6 精确率: 0.86
# 6 召回率: 0.81
# 6 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 7 训练数据量: 23
# 7 验证数据量: 3
# ———————————————— tensor(82.0513, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.81
# 7 精确率: 0.84
# 7 召回率: 0.81
# 7 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 257, np.int64(0): 448}
# 8 训练数据量: 23
# 8 验证数据量: 3
# ———————————————— tensor(94.8718, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.95
# 8 精确率: 0.95
# 8 召回率: 0.95
# 8 F1: 0.95
#
# 训练集类别分布: {np.int64(1): 262, np.int64(0): 443}
# 9 训练数据量: 23
# 9 验证数据量: 3
# ———————————————— tensor(93.5897, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.92
# 9 精确率: 0.93
# 9 召回率: 0.92
# 9 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 268, np.int64(0): 437}
# 10 训练数据量: 23
# 10 验证数据量: 3
# ———————————————— tensor(96.1538, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.95
# 10 精确率: 0.95
# 10 召回率: 0.95
# 10 F1: 0.95
#
# 平均准确率: 0.91
# 平均精确率: 0.92
# 平均召回率: 0.91
# 平均F1: 0.91
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.87
# 1 精确率: 0.87
# 1 召回率: 0.87
# 1 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.93
# 2 精确率: 0.94
# 2 召回率: 0.93
# 2 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.93
# 3 精确率: 0.95
# 3 召回率: 0.93
# 3 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.87
# 4 精确率: 0.90
# 4 召回率: 0.87
# 4 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.93
# 5 精确率: 0.96
# 5 召回率: 0.93
# 5 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.87
# 6 精确率: 0.87
# 6 召回率: 0.87
# 6 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.73
# 7 精确率: 0.77
# 7 召回率: 0.73
# 7 F1: 0.74
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.87
# 8 精确率: 0.96
# 8 召回率: 0.87
# 8 F1: 0.89
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.86
# 9 精确率: 0.86
# 9 召回率: 0.86
# 9 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(92.8571, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.93
# 10 精确率: 0.95
# 10 召回率: 0.93
# 10 F1: 0.93
#
# [[100  13]
#  [  5  30]]
# 平均准确率: 0.88
# 平均精确率: 0.90
# 平均召回率: 0.88
# 平均F1: 0.88

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2

# [[84 29]
#  [21 14]]
# 平均准确率: 0.66
# 平均精确率: 0.67
# 平均召回率: 0.66
# 平均F1: 0.63

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/only_SP2/train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 500 \
--batch_size 32 \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 训练集类别分布: {np.int64(1): 54, np.int64(0): 183}
# 1 训练数据量: 8
# 1 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.53
# 1 精确率: 0.60
# 1 召回率: 0.53
# 1 F1: 0.55
#
# 2 训练数据量: 8
# 2 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.73
# 2 精确率: 0.73
# 2 召回率: 0.73
# 2 F1: 0.73
#
# 3 训练数据量: 8
# 3 验证数据量: 1
# ———————————————— tensor(40.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.53
# 3 精确率: 0.83
# 3 召回率: 0.53
# 3 F1: 0.53
#
# 4 训练数据量: 8
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 4: Done
# 4 准确率: 0.67
# 4 精确率: 0.44
# 4 召回率: 0.67
# 4 F1: 0.53
#
# 5 训练数据量: 8
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.75
# 5 召回率: 0.87
# 5 F1: 0.80
#
# 6 训练数据量: 8
# 6 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.64
# 6 召回率: 0.80
# 6 F1: 0.71
#
# 7 训练数据量: 8
# 7 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.47
# 7 精确率: 0.56
# 7 召回率: 0.47
# 7 F1: 0.48
#
# 8 训练数据量: 8
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 8: Done
# 8 准确率: 0.93
# 8 精确率: 0.87
# 8 召回率: 0.93
# 8 F1: 0.90
#
# 9 训练数据量: 8
# 9 验证数据量: 1
# ———————————————— tensor(78.5714, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 9: Done
# 9 准确率: 0.79
# 9 精确率: 0.62
# 9 召回率: 0.79
# 9 F1: 0.69
#
# 10 训练数据量: 8
# 10 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.29
# 10 精确率: 0.66
# 10 召回率: 0.29
# 10 F1: 0.35
#
# [[84 29]
#  [21 14]]
# 平均准确率: 0.66
# 平均精确率: 0.67
# 平均召回率: 0.66
# 平均F1: 0.63

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1

# [[98 15]
#  [ 4 31]]
# 平均准确率: 0.87
# 平均精确率: 0.91
# 平均召回率: 0.87
# 平均F1: 0.88

# !python3 pretrain_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2

# !python3 finetune_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharMLP_best.pth.tar" \
--fine_model_path "./fine_CharMLP_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP2.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 1 训练数据量: 7
# 1 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.79
# 1 精确率: 0.80
# 1 召回率: 0.79
# 1 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 2 训练数据量: 7
# 2 验证数据量: 1
# ———————————————— tensor(83.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.75
# 2 精确率: 0.88
# 2 召回率: 0.75
# 2 F1: 0.77
#
# 训练集类别分布: {np.int64(1): 53, np.int64(0): 160}
# 3 训练数据量: 7
# 3 验证数据量: 1
# ———————————————— tensor(95.8333, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.88
# 3 精确率: 0.91
# 3 召回率: 0.88
# 3 F1: 0.89
#
# 训练集类别分布: {np.int64(1): 47, np.int64(0): 166}
# 4 训练数据量: 7
# 4 验证数据量: 1
# ———————————————— tensor(91.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.92
# 4 精确率: 0.93
# 4 召回率: 0.92
# 4 F1: 0.91
#
# 训练集类别分布: {np.int64(1): 48, np.int64(0): 165}
# 5 训练数据量: 7
# 5 验证数据量: 1
# ———————————————— tensor(95.8333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.79
# 5 精确率: 0.80
# 5 召回率: 0.79
# 5 F1: 0.80
#
# 训练集类别分布: {np.int64(1): 47, np.int64(0): 166}
# 6 训练数据量: 7
# 6 验证数据量: 1
# ———————————————— tensor(95.8333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.88
# 6 精确率: 0.88
# 6 召回率: 0.88
# 6 F1: 0.88
#
# 训练集类别分布: {np.int64(1): 46, np.int64(0): 167}
# 7 训练数据量: 7
# 7 验证数据量: 1
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.83
# 7 精确率: 0.85
# 7 召回率: 0.83
# 7 F1: 0.84
#
# 训练集类别分布: {np.int64(1): 49, np.int64(0): 165}
# 8 训练数据量: 7
# 8 验证数据量: 1
# ———————————————— tensor(86.9565, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.78
# 8 精确率: 0.80
# 8 召回率: 0.78
# 8 F1: 0.79
#
# 训练集类别分布: {np.int64(1): 50, np.int64(0): 164}
# 9 训练数据量: 7
# 9 验证数据量: 1
# ———————————————— tensor(91.3044, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.83
# 9 精确率: 0.86
# 9 召回率: 0.83
# 9 F1: 0.84
#
# 训练集类别分布: {np.int64(1): 50, np.int64(0): 164}
# 10 训练数据量: 7
# 10 验证数据量: 1
# ———————————————— tensor(91.3044, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.87
# 10 精确率: 0.93
# 10 召回率: 0.87
# 10 F1: 0.88
#
# 平均准确率: 0.83
# 平均精确率: 0.86
# 平均召回率: 0.83
# 平均F1: 0.84
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.93
# 1 精确率: 0.94
# 1 召回率: 0.93
# 1 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.87
# 2 精确率: 0.90
# 2 召回率: 0.87
# 2 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.87
# 3 精确率: 0.91
# 3 召回率: 0.87
# 3 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.93
# 4 精确率: 0.94
# 4 召回率: 0.93
# 4 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.80
# 5 精确率: 0.92
# 5 召回率: 0.80
# 5 F1: 0.83
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.80
# 6 精确率: 0.83
# 6 召回率: 0.80
# 6 F1: 0.81
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.93
# 7 精确率: 0.94
# 7 召回率: 0.93
# 7 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.80
# 8 精确率: 0.86
# 8 召回率: 0.80
# 8 F1: 0.83
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.86
# 9 精确率: 0.86
# 9 召回率: 0.86
# 9 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.93
# 10 精确率: 0.95
# 10 召回率: 0.93
# 10 F1: 0.93
#
# [[98 15]
#  [ 4 31]]
# 平均准确率: 0.87
# 平均精确率: 0.91
# 平均召回率: 0.87
# 平均F1: 0.88

# %%
# Move to the folder
# %cd /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2

# [[90 23]
#  [26  9]]
# 平均准确率: 0.67
# 平均精确率: 0.63
# 平均召回率: 0.67
# 平均F1: 0.64

# !python3 /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/only_SP2/train_MLP.py \
--train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--test_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 500 \
--batch_size 32 \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/only_SP2
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 500
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              SGD
# 	Save folder:            ./
# 	Saved values path:      ./saved_values.xlsx
# 	Test path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 	Train path:             /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 训练集类别分布: {np.int64(1): 240, np.int64(0): 398}
# 1 训练数据量: 20
# 1 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.27
# 1 精确率: 0.33
# 1 召回率: 0.27
# 1 F1: 0.27
#
# 2 训练数据量: 20
# 2 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.60
# 2 精确率: 0.64
# 2 召回率: 0.60
# 2 F1: 0.61
#
# 3 训练数据量: 20
# 3 验证数据量: 1
# ———————————————— tensor(73.3333, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 3: Done
# 3 准确率: 0.73
# 3 精确率: 0.54
# 3 召回率: 0.73
# 3 F1: 0.62
#
# 4 训练数据量: 20
# 4 验证数据量: 1
# ———————————————— tensor(66.6667, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.60
# 4 精确率: 0.60
# 4 召回率: 0.60
# 4 F1: 0.60
#
# 5 训练数据量: 20
# 5 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.75
# 5 召回率: 0.87
# 5 F1: 0.80
#
# 6 训练数据量: 20
# 6 验证数据量: 1
# ———————————————— tensor(86.6667, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.67
# 6 精确率: 0.62
# 6 召回率: 0.67
# 6 F1: 0.64
#
# 7 训练数据量: 20
# 7 验证数据量: 1
# ———————————————— tensor(80.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.60
# 7 精确率: 0.60
# 7 召回率: 0.60
# 7 F1: 0.60
#
# 8 训练数据量: 20
# 8 验证数据量: 1
# ———————————————— tensor(93.3333, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 8: Done
# 8 准确率: 0.93
# 8 精确率: 0.87
# 8 召回率: 0.93
# 8 F1: 0.90
#
# 9 训练数据量: 20
# 9 验证数据量: 1
# ———————————————— tensor(78.5714, device='cuda:0')
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 9: Done
# 9 准确率: 0.79
# 9 精确率: 0.62
# 9 召回率: 0.79
# 9 F1: 0.69
#
# 10 训练数据量: 20
# 10 验证数据量: 1
# ———————————————— tensor(85.7143, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.64
# 10 精确率: 0.70
# 10 召回率: 0.64
# 10 F1: 0.67
#
# [[90 23]
#  [26  9]]
# 平均准确率: 0.67
# 平均精确率: 0.63
# 平均召回率: 0.67
# 平均F1: 0.64

# %%
# Move to the working directory
# %cd /content/drive/MyDrive/Colab\ Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1

# [[109   4]
#  [  3  32]]
# 平均准确率: 0.95
# 平均精确率: 0.96
# 平均召回率: 0.95
# 平均F1: 0.95

# 🔁 Pretrain and Finetune CNN in one go
# !python3 pretrain_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--model_path "./CharMLP_best.pth.tar" \
--save_folder "./" \
--lr 0.001 \
--epochs 300 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--num_classes 2

# !python3 finetune_MLP.py \
--pre_train_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx" \
--tune_path "/content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx" \
--pre_model_path "./CharMLP_best.pth.tar" \
--fine_model_path "./fine_CharMLP_best.pth.tar" \
--saved_values_path "./saved_values.xlsx" \
--lr 0.001 \
--epochs 200 \
--batch_size 32 \
--optimizer Adam \
--lr_min 0.0001 \
--T_max 60 \
--dropout 0.2 \
--embedding_dim 16 \
--unfreeze_after_epochs 100 \
--tuning_strategy 3 \
--num_classes 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/classification/MLP/SP2_trans_SP1
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# Directory already exists.
#
# Configuration:
# 	T max:                  60
# 	Batch size:             32
# 	Checkpoint:             True
# 	Device:                 cuda
# 	Dropout:                0.2
# 	Embedding dim:          16
# 	Epochs:                 300
# 	Log result:             True
# 	Lr:                     0.001
# 	Lr min:                 0.0001
# 	Max length:             50
# 	Max norm:               400
# 	Model path:             ./CharMLP_best.pth.tar
# 	Num classes:            2
# 	Optimizer:              Adam
# 	Pre train path:         /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP3.xlsx
# 	Save folder:            ./
# 	Tune path:              /content/drive/MyDrive/Colab Notebooks/repo/SP_designer/data/BSP1.xlsx
# 训练集类别分布: {np.int64(1): 213, np.int64(0): 361}
# 1 训练数据量: 18
# 1 验证数据量: 2
# ———————————————— tensor(93.7500, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.92
# 1 精确率: 0.92
# 1 召回率: 0.92
# 1 F1: 0.92
#
# 训练集类别分布: {np.int64(1): 217, np.int64(0): 357}
# 2 训练数据量: 18
# 2 验证数据量: 2
# ———————————————— tensor(87.5000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 0.84
# 2 精确率: 0.85
# 2 召回率: 0.84
# 2 F1: 0.85
#
# 训练集类别分布: {np.int64(1): 211, np.int64(0): 363}
# 3 训练数据量: 18
# 3 验证数据量: 2
# ———————————————— tensor(92.1875, device='cuda:0')
# Fold 3: Done
# 3 准确率: 0.88
# 3 精确率: 0.88
# 3 召回率: 0.88
# 3 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 219, np.int64(0): 355}
# 4 训练数据量: 18
# 4 验证数据量: 2
# ———————————————— tensor(92.1875, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.86
# 4 精确率: 0.86
# 4 召回率: 0.86
# 4 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 213, np.int64(0): 361}
# 5 训练数据量: 18
# 5 验证数据量: 2
# ———————————————— tensor(89.0625, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.86
# 5 精确率: 0.86
# 5 召回率: 0.86
# 5 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 216, np.int64(0): 358}
# 6 训练数据量: 18
# 6 验证数据量: 2
# ———————————————— tensor(92.1875, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.84
# 6 精确率: 0.85
# 6 召回率: 0.84
# 6 F1: 0.84
#
# 训练集类别分布: {np.int64(1): 221, np.int64(0): 353}
# 7 训练数据量: 18
# 7 验证数据量: 2
# ———————————————— tensor(93.7500, device='cuda:0')
# Fold 7: Done
# 7 准确率: 0.94
# 7 精确率: 0.94
# 7 召回率: 0.94
# 7 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 214, np.int64(0): 360}
# 8 训练数据量: 18
# 8 验证数据量: 2
# ———————————————— tensor(96.8750, device='cuda:0')
# Fold 8: Done
# 8 准确率: 0.94
# 8 精确率: 0.94
# 8 召回率: 0.94
# 8 F1: 0.94
#
# 训练集类别分布: {np.int64(1): 219, np.int64(0): 356}
# 9 训练数据量: 18
# 9 验证数据量: 2
# ———————————————— tensor(92.0635, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.86
# 9 精确率: 0.87
# 9 召回率: 0.86
# 9 F1: 0.86
#
# 训练集类别分布: {np.int64(1): 217, np.int64(0): 358}
# 10 训练数据量: 18
# 10 验证数据量: 2
# ———————————————— tensor(93.6508, device='cuda:0')
# Fold 10: Done
# 10 准确率: 0.95
# 10 精确率: 0.95
# 10 召回率: 0.95
# 10 F1: 0.95
#
# 平均准确率: 0.89
# 平均精确率: 0.89
# 平均召回率: 0.89
# 平均F1: 0.89
# 🔹 Running in Google Colab
# Matplotlib backend set to 'Agg' for Colab
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 1 训练数据量: 5
# 1 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 1: Done
# 1 准确率: 0.93
# 1 精确率: 0.94
# 1 召回率: 0.93
# 1 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 2 训练数据量: 5
# 2 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 2: Done
# 2 准确率: 1.00
# 2 精确率: 1.00
# 2 召回率: 1.00
# 2 F1: 1.00
#
# 训练集类别分布: {np.int64(1): 31, np.int64(0): 102}
# 3 训练数据量: 5
# 3 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 3: Done
# 3 准确率: 1.00
# 3 精确率: 1.00
# 3 召回率: 1.00
# 3 F1: 1.00
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 4 训练数据量: 5
# 4 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 4: Done
# 4 准确率: 0.87
# 4 精确率: 0.87
# 4 召回率: 0.87
# 4 F1: 0.87
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 100}
# 5 训练数据量: 5
# 5 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 5: Done
# 5 准确率: 0.87
# 5 精确率: 0.93
# 5 召回率: 0.87
# 5 F1: 0.88
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 101}
# 6 训练数据量: 5
# 6 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(93.3333, device='cuda:0')
# Fold 6: Done
# 6 准确率: 0.93
# 6 精确率: 0.94
# 6 召回率: 0.93
# 6 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 30, np.int64(0): 103}
# 7 训练数据量: 5
# 7 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 7: Done
# 7 准确率: 1.00
# 7 精确率: 1.00
# 7 召回率: 1.00
# 7 F1: 1.00
#
# 训练集类别分布: {np.int64(1): 34, np.int64(0): 99}
# 8 训练数据量: 5
# 8 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 8: Done
# 8 准确率: 1.00
# 8 精确率: 1.00
# 8 召回率: 1.00
# 8 F1: 1.00
#
# 训练集类别分布: {np.int64(1): 32, np.int64(0): 102}
# 9 训练数据量: 5
# 9 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 9: Done
# 9 准确率: 0.93
# 9 精确率: 0.95
# 9 召回率: 0.93
# 9 F1: 0.93
#
# 训练集类别分布: {np.int64(1): 33, np.int64(0): 101}
# 10 训练数据量: 5
# 10 验证数据量: 1
# —————— 参数已解冻 ——————
# ———————————————— tensor(100.0000, device='cuda:0')
# Fold 10: Done
# 10 准确率: 1.00
# 10 精确率: 1.00
# 10 召回率: 1.00
# 10 F1: 1.00
#
# [[109   4]
#  [  3  32]]
# 平均准确率: 0.95
# 平均精确率: 0.96
# 平均召回率: 0.95
# 平均F1: 0.95
